# %% [markdown]
# <a href="https://colab.research.google.com/github/Facco-Bruno/Alura-Python/blob/Master/Treatment_and_Analysis_with_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dados = pd.read_csv('aluguel.csv', sep=';')

# %%
dados.head(5)
# Out:
#                       Tipo           Bairro  ...  Condominio    IPTU
# 0                Quitinete       Copacabana  ...       500.0    60.0
# 1                     Casa  Jardim Botânico  ...         NaN     NaN
# 2  Conjunto Comercial/Sala  Barra da Tijuca  ...      4020.0  1111.0
# 3              Apartamento           Centro  ...       390.0    20.0
# 4              Apartamento     Higienópolis  ...       230.0     NaN
#
# [5 rows x 9 columns]

# %%
dados.info
# Out:
# <bound method DataFrame.info of                           Tipo                Bairro  ...  Condominio    IPTU
# 0                    Quitinete            Copacabana  ...       500.0    60.0
# 1                         Casa       Jardim Botânico  ...         NaN     NaN
# 2      Conjunto Comercial/Sala       Barra da Tijuca  ...      4020.0  1111.0
# 3                  Apartamento                Centro  ...       390.0    20.0
# 4                  Apartamento          Higienópolis  ...       230.0     NaN
# ...                        ...                   ...  ...         ...     ...
# 32955                Quitinete                Centro  ...       350.0    25.0
# 32956              Apartamento           Jacarepaguá  ...       800.0    40.0
# 32957              Apartamento  São Francisco Xavier  ...       509.0    37.0
# 32958              Apartamento                Leblon  ...       760.0     NaN
# 32959  Conjunto Comercial/Sala                Centro  ...      4206.0  1109.0
#
# ...

# %%
dados.describe()
# Out:
#             Quartos         Vagas  ...    Condominio          IPTU
# count  32960.000000  32960.000000  ...  2.886700e+04  2.272300e+04
# mean       1.771390      1.749059  ...  2.388062e+03  2.364410e+03
# std        1.717869     20.380402  ...  3.918496e+04  1.795641e+05
# min        0.000000      0.000000  ...  1.000000e+00  1.000000e+00
# 25%        0.000000      0.000000  ...  5.900000e+02  1.100000e+02
# 50%        2.000000      1.000000  ...  9.900000e+02  2.500000e+02
# 75%        3.000000      2.000000  ...  1.800000e+03  6.970000e+02
# max      100.000000   1966.000000  ...  6.552570e+06  2.705307e+07
#
# [8 rows x 7 columns]

# %%
pd.DataFrame(dados.dtypes)
# Out:
#                   0
# Tipo         object
# Bairro       object
# Quartos       int64
# Vagas         int64
# Suites        int64
# Area          int64
# Valor       float64
# Condominio  float64
# IPTU        float64

# %%
print('A base de dados apresenta {} registros (imóveis) e {} variáveis'.format(dados.shape[0], dados.shape[1]))
# Out:
# A base de dados apresenta 32960 registros (imóveis) e 9 variáveis

# %%
json = open('aluguel.json')
print(json.read())
# Out:
# [{"Tipo":"Quitinete","Bairro":"Copacabana","Quartos":1,"Vagas":0,"Suites":0,"Area":40,"Valor":1700.0,"Condominio":500.0,"IPTU":60.0},
# {"Tipo":"Casa","Bairro":"Jardim Bot\u00e2nico","Quartos":2,"Vagas":0,"Suites":1,"Area":100,"Valor":7000.0,"Condominio":null,"IPTU":null},
# {"Tipo":"Conjunto Comercial\/Sala","Bairro":"Barra da Tijuca","Quartos":0,"Vagas":4,"Suites":0,"Area":150,"Valor":5200.0,"Condominio":4020.0,"IPTU":1111.0},
# {"Tipo":"Apartamento","Bairro":"Centro","Quartos":1,"Vagas":0,"Suites":0,"Area":15,"Valor":800.0,"Condominio":390.0,"IPTU":20.0},
# {"Tipo":"Apartamento","Bairro":"Higien\u00f3polis","Quartos":1,"Vagas":0,"Suites":0,"Area":48,"Valor":800.0,"Condominio":230.0,"IPTU":null},
# {"Tipo":"Apartamento","Bairro":"Vista Alegre","Quartos":3,"Vagas":1,"Suites":0,"Area":70,"Valor":1200.0,"Condominio":null,"IPTU":null},
# {"Tipo":"Apartamento","Bairro":"Cachambi","Quartos":2,"Vagas":0,"Suites":0,"Area":50,"Valor":1300.0,"Condominio":301.0,"IPTU":17.0},
# ...

# %%
df_json = pd.read_json('aluguel.json')
df_json
# Out:
#                       Tipo           Bairro  Quartos  ...  Valor  Condominio    IPTU
# 0                Quitinete       Copacabana        1  ...   1700       500.0    60.0
# 1                     Casa  Jardim Botânico        2  ...   7000         NaN     NaN
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0  ...   5200      4020.0  1111.0
# 3              Apartamento           Centro        1  ...    800       390.0    20.0
# 4              Apartamento     Higienópolis        1  ...    800       230.0     NaN
# 5              Apartamento     Vista Alegre        3  ...   1200         NaN     NaN
# 6              Apartamento         Cachambi        2  ...   1300       301.0    17.0
# 7       Casa de Condomínio  Barra da Tijuca        5  ...  22000         NaN     NaN
# 8       Casa de Condomínio            Ramos        2  ...   1000         NaN     NaN
# 9  Conjunto Comercial/Sala           Centro        0  ...  35000     19193.0  3030.0
#
# [10 rows x 9 columns]

# %%
tipo_de_imovel = dados['Tipo']

# %%
tipo_de_imovel
# Out:
# 0                      Quitinete
# 1                           Casa
# 2        Conjunto Comercial/Sala
# 3                    Apartamento
# 4                    Apartamento
#                   ...
# 32955                  Quitinete
# 32956                Apartamento
# 32957                Apartamento
# 32958                Apartamento
# 32959    Conjunto Comercial/Sala
# Name: Tipo, Length: 32960, dtype: object

# %%
tipo_de_imovel.drop_duplicates()
# Out:
# 0                          Quitinete
# 1                               Casa
# 2            Conjunto Comercial/Sala
# 3                        Apartamento
# 7                 Casa de Condomínio
# 16                    Prédio Inteiro
# 17                              Flat
# 29                        Loja/Salão
# 80           Galpão/Depósito/Armazém
# 83                    Casa Comercial
# 117                     Casa de Vila
# 159                   Terreno Padrão
# 207                      Box/Garagem
# 347                             Loft
# 589      Loja Shopping/ Ct Comercial
# 2157                         Chácara
# 3354           Loteamento/Condomínio
# 4379                           Sítio
# 4721                   Pousada/Chalé
# 6983                          Studio
# 9687                           Hotel
# 23614                      Indústria
# Name: Tipo, dtype: object

# %%
tipo_de_imovel.drop_duplicates(inplace = True)

# %%
tipo_de_imovel
# Out:
# 0                          Quitinete
# 1                               Casa
# 2            Conjunto Comercial/Sala
# 3                        Apartamento
# 7                 Casa de Condomínio
# 16                    Prédio Inteiro
# 17                              Flat
# 29                        Loja/Salão
# 80           Galpão/Depósito/Armazém
# 83                    Casa Comercial
# 117                     Casa de Vila
# 159                   Terreno Padrão
# 207                      Box/Garagem
# 347                             Loft
# 589      Loja Shopping/ Ct Comercial
# 2157                         Chácara
# 3354           Loteamento/Condomínio
# 4379                           Sítio
# 4721                   Pousada/Chalé
# 6983                          Studio
# 9687                           Hotel
# 23614                      Indústria
# Name: Tipo, dtype: object

# %%
tipo_de_imovel = pd.DataFrame(tipo_de_imovel)

# %%
tipo_de_imovel
# Out:
#                               Tipo
# 0                        Quitinete
# 1                             Casa
# 2          Conjunto Comercial/Sala
# 3                      Apartamento
# 7               Casa de Condomínio
# 16                  Prédio Inteiro
# 17                            Flat
# 29                      Loja/Salão
# 80         Galpão/Depósito/Armazém
# 83                  Casa Comercial
# 117                   Casa de Vila
# 159                 Terreno Padrão
# 207                    Box/Garagem
# 347                           Loft
# 589    Loja Shopping/ Ct Comercial
# 2157                       Chácara
# 3354         Loteamento/Condomínio
# 4379                         Sítio
# 4721                 Pousada/Chalé
# 6983                        Studio
# 9687                         Hotel
# 23614                    Indústria

# %%
tipo_de_imovel.index = range(tipo_de_imovel.shape[0])

# %%
tipo_de_imovel
# Out:
#                            Tipo
# 0                     Quitinete
# 1                          Casa
# 2       Conjunto Comercial/Sala
# 3                   Apartamento
# 4            Casa de Condomínio
# 5                Prédio Inteiro
# 6                          Flat
# 7                    Loja/Salão
# 8       Galpão/Depósito/Armazém
# 9                Casa Comercial
# 10                 Casa de Vila
# 11               Terreno Padrão
# 12                  Box/Garagem
# 13                         Loft
# 14  Loja Shopping/ Ct Comercial
# 15                      Chácara
# 16        Loteamento/Condomínio
# 17                        Sítio
# 18                Pousada/Chalé
# 19                       Studio
# 20                        Hotel
# 21                    Indústria

# %%
tipo_de_imovel.columns.name = 'id'
tipo_de_imovel
# Out:
# id                         Tipo
# 0                     Quitinete
# 1                          Casa
# 2       Conjunto Comercial/Sala
# 3                   Apartamento
# 4            Casa de Condomínio
# 5                Prédio Inteiro
# 6                          Flat
# 7                    Loja/Salão
# 8       Galpão/Depósito/Armazém
# 9                Casa Comercial
# 10                 Casa de Vila
# 11               Terreno Padrão
# 12                  Box/Garagem
# 13                         Loft
# 14  Loja Shopping/ Ct Comercial
# 15                      Chácara
# 16        Loteamento/Condomínio
# 17                        Sítio
# 18                Pousada/Chalé
# 19                       Studio
# 20                        Hotel
# 21                    Indústria

# %%
data = [[1, 2, 3], 
        [4, 5, 6], 
        [7, 8, 9]]

# %%
index = ['Linha' + str(i) for i in range(3)]

# %%
columns = ['Coluna' + str(i) for i in range(3)]

# %%
df2 = pd.DataFrame(data = data, index = index, columns = columns)
df2
# Out:
#         Coluna0  Coluna1  Coluna2
# Linha0        1        2        3
# Linha1        4        5        6
# Linha2        7        8        9

# %%
df3 = df2
df3
# Out:
#         Coluna0  Coluna1  Coluna2
# Linha0        1        2        3
# Linha1        4        5        6
# Linha2        7        8        9

# %%
df3[df3 > 0] = 'A'
df3
# Out:
#        Coluna0 Coluna1 Coluna2
# Linha0       A       A       A
# Linha1       A       A       A
# Linha2       A       A       A

# %%
df4 = df2

# %%
df4[df4 > 0] = 'B'
df4
# Out:
#        Coluna0 Coluna1 Coluna2
# Linha0       B       B       B
# Linha1       B       B       B
# Linha2       B       B       B

# %%
df5 = pd.concat([df2, df3, df4])
df5
# Out:
#        Coluna0 Coluna1 Coluna2
# Linha0       B       B       B
# Linha1       B       B       B
# Linha2       B       B       B
# Linha0       A       A       A
# Linha1       A       A       A
# Linha2       A       A       A
# Linha0       B       B       B
# Linha1       B       B       B
# Linha2       B       B       B

# %%
df4 = pd.concat([df2, df3, df4], axis = 1)
df4
# Out:
#        Coluna0 Coluna1 Coluna2 Coluna0 Coluna1 Coluna2 Coluna0 Coluna1 Coluna2
# Linha0       B       B       B       A       A       A       B       B       B
# Linha1       B       B       B       A       A       A       B       B       B
# Linha2       B       B       B       A       A       A       B       B       B

# %%
df1 = pd.DataFrame({'A': {'X': 1}, 'B': {'X': 2}})
df2 = pd.DataFrame({'C': {'X': 3}, 'D': {'X': 4}})
pd.concat([df1, df2])
# Out:
#      A    B    C    D
# X  1.0  2.0  NaN  NaN
# X  NaN  NaN  3.0  4.0

# %%
dados = [('A', 'B'), ('C', 'D')]
df = pd.DataFrame(dados, columns = ['L1', 'L2'],  index = ['C1', 'C2'])
df
# Out:
#    L1 L2
# C1  A  B
# C2  C  D

# %%
dados = [[1, 2, 3], [4, 5, 6]]
index = 'X,Y'.split(',')
columns = list('CBA')[::-1]
df = pd.DataFrame(dados, index, columns)
df
# Out:
#    A  B  C
# X  1  2  3
# Y  4  5  6

# %%
dados = {'A': {'X': 1, 'Y': 3}, 'B': {'X': 2, 'Y': 4}}
df = pd.DataFrame(dados)
df
# Out:
#    A  B
# X  1  2
# Y  3  4

# %%
dados.head(10)
# Out:
#                       Tipo           Bairro  ...  Condominio    IPTU
# 0                Quitinete       Copacabana  ...       500.0    60.0
# 1                     Casa  Jardim Botânico  ...         NaN     NaN
# 2  Conjunto Comercial/Sala  Barra da Tijuca  ...      4020.0  1111.0
# 3              Apartamento           Centro  ...       390.0    20.0
# 4              Apartamento     Higienópolis  ...       230.0     NaN
# 5              Apartamento     Vista Alegre  ...         NaN     NaN
# 6              Apartamento         Cachambi  ...       301.0    17.0
# 7       Casa de Condomínio  Barra da Tijuca  ...         NaN     NaN
# 8       Casa de Condomínio            Ramos  ...         NaN     NaN
# 9  Conjunto Comercial/Sala           Centro  ...     19193.0  3030.0
#
# [10 rows x 9 columns]

# %%
list(dados['Tipo'].drop_duplicates())
# Out:
# ['Quitinete',
#  'Casa',
#  'Conjunto Comercial/Sala',
#  'Apartamento',
#  'Casa de Condomínio',
#  'Prédio Inteiro',
#  'Flat',
#  'Loja/Salão',
#  'Galpão/Depósito/Armazém',
#  'Casa Comercial',
#  'Casa de Vila',
#  'Terreno Padrão',
#  'Box/Garagem',
#  'Loft',
#  'Loja Shopping/ Ct Comercial',
#  'Chácara',
#  'Loteamento/Condomínio',
#  'Sítio',
#  'Pousada/Chalé',
#  'Studio',
#  'Hotel',
#  'Indústria']

# %%
residencial = ['Quitinete', 
'Casa',
'Apartamento',
'Casa de Condomínio',
'Casa de Vila']

# %%
dados['Tipo'].isin(residencial).head(10)
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9    False
# Name: Tipo, dtype: bool

# %%
selecao = dados['Tipo'].isin(residencial)

# %%
dados_residencial = dados[selecao]
dados_residencial
# Out:
#               Tipo                Bairro  Quartos  ...   Valor  Condominio  IPTU
# 0        Quitinete            Copacabana        1  ...  1700.0       500.0  60.0
# 1             Casa       Jardim Botânico        2  ...  7000.0         NaN   NaN
# 3      Apartamento                Centro        1  ...   800.0       390.0  20.0
# 4      Apartamento          Higienópolis        1  ...   800.0       230.0   NaN
# 5      Apartamento          Vista Alegre        3  ...  1200.0         NaN   NaN
# ...            ...                   ...      ...  ...     ...         ...   ...
# 32953  Apartamento                 Méier        2  ...   900.0       490.0  48.0
# 32955    Quitinete                Centro        0  ...   800.0       350.0  25.0
# 32956  Apartamento           Jacarepaguá        3  ...  1800.0       800.0  40.0
# 32957  Apartamento  São Francisco Xavier        2  ...  1400.0       509.0  37.0
# 32958  Apartamento                Leblon        2  ...  3000.0       760.0   NaN
#
# ...

# %%
list(dados_residencial['Tipo'].drop_duplicates())
# Out:
# ['Quitinete', 'Casa', 'Apartamento', 'Casa de Condomínio', 'Casa de Vila']

# %%
dados_residencial.shape[0]
# Out:
# 22580

# %%
dados_residencial.index = range(dados_residencial.shape[0])

# %%
dados_residencial
# Out:
#               Tipo                Bairro  Quartos  ...   Valor  Condominio  IPTU
# 0        Quitinete            Copacabana        1  ...  1700.0       500.0  60.0
# 1             Casa       Jardim Botânico        2  ...  7000.0         NaN   NaN
# 2      Apartamento                Centro        1  ...   800.0       390.0  20.0
# 3      Apartamento          Higienópolis        1  ...   800.0       230.0   NaN
# 4      Apartamento          Vista Alegre        3  ...  1200.0         NaN   NaN
# ...            ...                   ...      ...  ...     ...         ...   ...
# 22575  Apartamento                 Méier        2  ...   900.0       490.0  48.0
# 22576    Quitinete                Centro        0  ...   800.0       350.0  25.0
# 22577  Apartamento           Jacarepaguá        3  ...  1800.0       800.0  40.0
# 22578  Apartamento  São Francisco Xavier        2  ...  1400.0       509.0  37.0
# 22579  Apartamento                Leblon        2  ...  3000.0       760.0   NaN
#
# ...

# %%
import pandas as pd

numeros = [i for i in range(11)]
letras = [chr(i + 65) for i in range(11)]
nome_coluna = ['N']

df = pd.DataFrame(data = numeros, index = letras, columns = nome_coluna)

# %%
df
# Out:
#     N
# A   0
# B   1
# C   2
# D   3
# E   4
# F   5
# G   6
# H   7
# I   8
# J   9
# K  10

# %%
selecao = df['N'].isin([i for i in range(11) if i % 2 == 0])
df = df[selecao]
df
# Out:
#     N
# A   0
# C   2
# E   4
# G   6
# I   8
# K  10

# %%
dados_residencial.head(10)
# Out:
#                  Tipo           Bairro  Quartos  ...    Valor  Condominio  IPTU
# 0           Quitinete       Copacabana        1  ...   1700.0       500.0  60.0
# 1                Casa  Jardim Botânico        2  ...   7000.0         NaN   NaN
# 2         Apartamento           Centro        1  ...    800.0       390.0  20.0
# 3         Apartamento     Higienópolis        1  ...    800.0       230.0   NaN
# 4         Apartamento     Vista Alegre        3  ...   1200.0         NaN   NaN
# 5         Apartamento         Cachambi        2  ...   1300.0       301.0  17.0
# 6  Casa de Condomínio  Barra da Tijuca        5  ...  22000.0         NaN   NaN
# 7  Casa de Condomínio            Ramos        2  ...   1000.0         NaN   NaN
# 8         Apartamento           Centro        1  ...   1200.0         NaN   NaN
# 9         Apartamento           Grajaú        2  ...   1500.0       642.0  74.0
#
# [10 rows x 9 columns]

# %%
aps = dados_residencial[dados_residencial['Tipo'] == 'Apartamento']
aps
# Out:
#               Tipo                Bairro  Quartos  ...   Valor  Condominio  IPTU
# 2      Apartamento                Centro        1  ...   800.0       390.0  20.0
# 3      Apartamento          Higienópolis        1  ...   800.0       230.0   NaN
# 4      Apartamento          Vista Alegre        3  ...  1200.0         NaN   NaN
# 5      Apartamento              Cachambi        2  ...  1300.0       301.0  17.0
# 8      Apartamento                Centro        1  ...  1200.0         NaN   NaN
# ...            ...                   ...      ...  ...     ...         ...   ...
# 22573  Apartamento        Vila Valqueire        2  ...  1000.0       550.0   NaN
# 22575  Apartamento                 Méier        2  ...   900.0       490.0  48.0
# 22577  Apartamento           Jacarepaguá        3  ...  1800.0       800.0  40.0
# 22578  Apartamento  São Francisco Xavier        2  ...  1400.0       509.0  37.0
# 22579  Apartamento                Leblon        2  ...  3000.0       760.0   NaN
#
# ...

# %%
aps.shape
# Out:
# (19532, 9)

# %%
selecao = (dados_residencial['Tipo'] == 'Casa') | (dados_residencial['Tipo'] == 'Casa de Condomínio') | (dados_residencial['Tipo'] == 'Casa de Vila')

casa = dados_residencial[selecao]

# %%
casa
# Out:
#                      Tipo                   Bairro  ...  Condominio    IPTU
# 1                    Casa          Jardim Botânico  ...         NaN     NaN
# 6      Casa de Condomínio          Barra da Tijuca  ...         NaN     NaN
# 7      Casa de Condomínio                    Ramos  ...         NaN     NaN
# 14     Casa de Condomínio                  Taquara  ...         NaN     NaN
# 18     Casa de Condomínio          Barra da Tijuca  ...      2695.0     NaN
# ...                   ...                      ...  ...         ...     ...
# 22545  Casa de Condomínio  Freguesia (Jacarepaguá)  ...       530.0  1250.0
# 22547                Casa            Bento Ribeiro  ...         NaN     NaN
# 22555  Casa de Condomínio          Barra da Tijuca  ...      3000.0     NaN
# 22558                Casa                   Centro  ...         NaN    80.0
# 22574  Casa de Condomínio          Barra da Tijuca  ...      1711.0  2332.0
#
# [2212 rows x 9 columns]

# %%
casa.shape
# Out:
# (2212, 9)

# %%
#Selecione os imóveis com área entre 60 e 100 metros quadrados, incluindo os limites.
#60 <= Area <=100
selecao = (dados_residencial['Area'] >= 60) & (dados_residencial['Area'] <= 100)
n3 = dados_residencial[selecao].shape[0]
n3
# Out:
# 8719

# %%
#Selecione os imóveis que tenham pelo menos 4 quartos e aluguel menor que R$ 2.000,00.
selecao = (dados_residencial['Quartos'] >= 4) & (dados_residencial['Valor'] < 2000)
n4 = dados_residencial[selecao].shape[0]
n4
# Out:
# 41
